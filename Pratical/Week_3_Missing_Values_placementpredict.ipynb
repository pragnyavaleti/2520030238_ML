# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/placement_predict_50k Dataset (1).csv")

# Fill missing numerical values with column mean
#inplace=True tells pandas to modify the original DataFrame directly, instead of creating a new DataFrame.
df.fillna(df.mean(numeric_only=True), inplace=True)

# Save the updated dataset to a new CSV file
#index=False tells pandas not to save the row numbers (index) into the CSV file.
df.to_csv("placementfilled.csv", index=False)

# Check if any missing values remain
print(df.isnull().sum())

print("\nNew dataset saved as 'plzcementfilled.csv'")
# Out:
# StudentID             0
# Gender                0
# City                  0
# CollegeTier           0
# Stream                0
# Specialisation        0
# Hostel                0
# HistoryOfBacklogs     0
# SGPA_Sem1             0
# SGPA_Sem2             0
# SGPA_Sem3             0
# SGPA_Sem4             0
# SGPA_Sem5             0
# SGPA_Sem6             0
# SGPA_Sem7             0
# SGPA_Sem8             0
# CGPA                  0
# AttendancePercent     0
# Internships           0
# Projects              0
# Workshops             0
# Certifications        0
# Publications          0
# AptitudeTestScore     0
# SoftSkillsRating      0
# CodingTestScore       0
# MockInterviewScore    0
# ExtraCurricular       0
# CGPA_Tier             0
# PlacementStatus       0
# IsAnomaly             0
# Salary Package        0
# dtype: int64
#
# New dataset saved as 'plzcementfilled.csv'

# %%
import pandas as pd

df = pd.read_csv("/content/placement_predict_50k Dataset (1) (1).csv")

# Fill missing categorical values with mode
for col in df.select_dtypes(include='object').columns:
    df[col].fillna(df[col].mode()[0], inplace=True)
df.to_csv("placementfilledcat.csv", index=False)
print(df.isnull().sum())
# Out:
# /tmp/ipykernel_1169/2902383744.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# StudentID                0
# Gender                   0
# City                     0
# CollegeTier              0
# Stream                   0
# Specialisation           0
# Hostel                   0
# HistoryOfBacklogs        0
# SGPA_Sem1                0
# SGPA_Sem2                0
# SGPA_Sem3                0
# SGPA_Sem4                0
# SGPA_Sem5                0
# ...

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/placementfilledcat.csv")

# Identify categorical columns
cat_cols = df.select_dtypes(include=['object']).columns

# Apply One-Hot Encoding
df = pd.get_dummies(df, columns=cat_cols, drop_first=True, dtype=int)

# Display first 5 rows
print(df.head())
#print(df)
# Check the new column names
print(df.columns)
# Out:
#    StudentID  SGPA_Sem1  SGPA_Sem2  SGPA_Sem3  SGPA_Sem4  SGPA_Sem5  \
# 0          1       6.02       6.54       6.52       6.00       6.47
# 1          2       5.84       5.12       5.34       5.18       5.03
# 2          3       4.91       5.29       5.49       5.73       5.33
# 3          4       7.67       8.03       8.08       7.64       6.86
# 4          5       8.14       8.97       8.36       8.55       8.55
#
#    SGPA_Sem6  SGPA_Sem7  SGPA_Sem8  CGPA  ...  Stream_EE  Stream_IT  \
# 0       5.91       6.49       5.50  6.29  ...          0          0
# 1       4.93       5.40       5.13  5.23  ...          0          0
# 2       5.88       5.82       5.67  5.52  ...          0          1
# 3       7.10       7.56       7.39  7.51  ...          0          0
# 4       8.38       9.10       8.86  8.65  ...          0          1
#
#    Stream_Mechanical  Specialisation_DataScience  Specialisation_Embedded  \
# ...

# %% [markdown]
# 1) drop_first=True:
# This tells pandas to remove the first category from each categorical feature.
# Without drop_first=True
# | Gender_Female | Gender_Male |
# | ------------- | ----------- |
# | 0             | 1           |
# | 1             | 0           |
# | 0             | 1           |
#
# With drop_first=True:
# | Gender_Male |
# | ----------- |
# | 1           |
# | 0           |
# | 1           |
#
# 2) dtype=int: converts Categorical into numerical. (Eg: True->1 and False->0)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load dataset
df = pd.read_csv("/content/placementfilledcat.csv")

# Select only two numerical features
X = df[['CGPA', 'AptitudeTestScore']]

# Apply Standard Scaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert to DataFrame
scaled_df = pd.DataFrame(X_scaled, columns=['CodingTestScore', 'AptitudeTestScore'])

print("Original Data")
print(X.head())

print("\nAfter Standard Scaling")
print(scaled_df.head())
# Out:
# Original Data
#    CGPA  AptitudeTestScore
# 0  6.29               66.7
# 1  5.23               48.2
# 2  5.52               73.8
# 3  7.51               69.8
# 4  8.65               73.1
#
# After Standard Scaling
#    CodingTestScore  AptitudeTestScore
# 0        -0.591800          -0.140531
# 1        -1.247875          -1.344561
# 2        -1.068383           0.321557
# 3         0.163305           0.061226
# 4         0.868894           0.275999

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Load dataset
df = pd.read_csv("/content/placementfilledcat.csv")

# Select only two numerical features
X = df[['CGPA', 'AptitudeTestScore']]

# Apply Min-Max Scaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Convert to DataFrame
scaled_df = pd.DataFrame(X_scaled, columns=['CGPA', 'AptitudeTestScore'])

print("Original Data")
print(X.head())

print("\nAfter Min-Max Scaling")
print(scaled_df.head())
# Out:
# Original Data
#    CGPA  AptitudeTestScore
# 0  6.29               66.7
# 1  5.23               48.2
# 2  5.52               73.8
# 3  7.51               69.8
# 4  8.65               73.1
#
# After Min-Max Scaling
#        CGPA  AptitudeTestScore
# 0  0.381667           0.524286
# 1  0.205000           0.260000
# 2  0.253333           0.625714
# 3  0.585000           0.568571
# 4  0.775000           0.615714
